# %% [markdown]
# MAJI NDOGO PROJECT
#
# Integrated project:
#
# Maji Ndogo is a country facing water related problem. The president of the country; Aziza Naledi has contracted some field workers and a Data Analytics Company to collect data from the people using the various types of water and to help her come up with data-based solutions.
#
# The survey has come to a successful end.
#
# Beginning our data-driven journey in Maji Ndogo (Part 1)
# In this first part of the integrated project, I will dive into Maji Ndogo's expansive database containing 60,000 records spread across various tables. As I navigate this trove of data, I will use basic queries to familiarise myself with the content of each table. Along the way, I will also refine some data using DML(Data Manupulation Language).

# %% [markdown]
# Connecting to MySQL database

# %%
# Loading and activating the SQL extention to allow the execution of SQL in a Jupyter notebook

# %load_ext sql

# %%
# Establishing a connection to the local database

# %sql mysql+pymysql://root:password@localhost:3306/md_water_services
# Out:
# 'Connected: root@md_water_services'

# %% [markdown]
# Getting to Know my datasets

# %%
# %%sql
#
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 9 rows affected.
# [('data_dictionary',),
#  ('employee',),
#  ('global_water_access',),
#  ('location',),
#  ('visits',),
#  ('water_quality',),
#  ('water_source',),
#  ('well_pollution',),
#  ('well_pollution_copy',)]

# %%
# %%sql
#
# # Fetching records from the location table
#
# SELECT
#     *
# FROM
#     location
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('AkHa00000', '2 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00001', '10 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00002', '9 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00003', '139 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00004', '17 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00005', '125 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00006', '98 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00007', '21 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00008', '11 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban'),
#  ('AkHa00009', '6 Addis Ababa Road', 'Akatsi', 'Harare', 'Urban')]

# %% [markdown]
# Task 2: Dive into the water sources

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     water_source
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('AkHa00000224', 'tap_in_home', 956),
#  ('AkHa00001224', 'tap_in_home_broken', 930),
#  ('AkHa00002224', 'tap_in_home_broken', 486),
#  ('AkHa00003224', 'well', 364),
#  ('AkHa00004224', 'tap_in_home_broken', 942)]

# %%
# %%sql
#
# # Taking a look at the Data dictionary table to get more info about the tables and the various columns
#
# SELECT
#     *
# FROM
#     data_dictionary
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 49 rows affected.
# [('employee', 'assigned_employee_id', 'Unique ID assigned to each employee', 'INT', 'visits'),
#  ('employee', 'employee_name', 'Name of the employee', 'VARCHAR(255)', ''),
#  ('employee', 'phone_number', 'Contact number of the employee', 'VARCHAR(15)', ''),
#  ('employee', 'email', 'Email address of the employee', 'VARCHAR(255)', ''),
#  ('employee', 'address', 'Residential address of the employee', 'VARCHAR(255)', ''),
#  ('employee', 'town_name', 'Name of the town where the employee resides', 'VARCHAR(255)', ''),
#  ('employee', 'province_name', 'Name of the province where the employee resides', 'VARCHAR(255)', ''),
#  ('employee', 'position', 'Position or job title of the employee', 'VARCHAR(255)', ''),
#  ('visits', 'record_id', 'Unique ID assigned to each visit', 'int', 'water_quality, water_source'),
#  ('visits', 'location_id', 'ID of the location visited', 'varchar(255)', 'location'),
# ...

# %% [markdown]
# Diving into the water sources
# We need to understand the types of water sources we're dealing with.

# %%
# %%sql
#
# #   querying the unique types of water resources
#
# SELECT
#     DISTINCT(type_of_water_source)
# FROM
#     water_source;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('tap_in_home',),
#  ('tap_in_home_broken',),
#  ('well',),
#  ('shared_tap',),
#  ('river',)]

# %% [markdown]
# The various source types and a little info on them:
# 1. *River* - People collect drinking water along a river. This is an open water source that millions of people use in Maji Ndogo. Water from a river has a high risk of being contaminated with biological and other pollutants, so it is the worst source of water possible.
#
# 2. *Well* - These sources draw water from underground sources, and are commonly shared by communities. Since these are closed water sources, contamination is much less likely compared to a river. Unfortunately, due to the aging infrastructure and the corruption of officials in the past, many of our wells are not clean.
#
# 3. *Shared tap* - This is a tap in a public area shared by communities.
#
# 4. *Tap in home* - These are taps that are inside the homes of our citizens. On average about 6 people live together in Maji Ndogo, so
# each of these taps serves about 6 people.
#
# 5. *Broken tap in home* - These are taps that have been installed in a citizen’s home, but the infrastructure connected to that tap is not functional. This can be due to burst pipes, broken pumps or water treatment plants that are not working.

# %% [markdown]
# *An important note on the home taps*: About 6-10 million people have running water installed in their homes in Maji Ndogo, including
# broken taps. If we were to document this, we would have a row of data for each home, so that one record is one tap. That means the
# database would contain about 1 million rows of data, which may slow the systems down. For now, the surveyors combined the data of
# many households together into a single record.

# %% [markdown]
# Task 3: Unpack visits to water sources

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     visits
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'SoIl32582', 'SoIl32582224', datetime.datetime(2021, 1, 1, 9, 10), 1, 15, 12),
#  (1, 'KiRu28935', 'KiRu28935224', datetime.datetime(2021, 1, 1, 9, 17), 1, 0, 46),
#  (2, 'HaRu19752', 'HaRu19752224', datetime.datetime(2021, 1, 1, 9, 36), 1, 62, 40),
#  (3, 'AkLu01628', 'AkLu01628224', datetime.datetime(2021, 1, 1, 9, 53), 1, 0, 1),
#  (4, 'AkRu03357', 'AkRu03357224', datetime.datetime(2021, 1, 1, 10, 11), 1, 28, 14)]

# %% [markdown]
# Task 4: Assess the quality of water sources
# The quality of our water sources is the whole point of this survey.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     water_quality
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 0, 1), (1, 1, 1), (2, 5, 1), (3, 10, 1), (4, 4, 1)]

# %% [markdown]
# The surveyors only made multiple visits to shared taps and did not revisit other types of water sources. So
# there should be no records of second visits to locations where there are good water sources, like taps in homes.
# Lets see if this is true. So I am going to query out tap_in_home sources where visits = 2 to see if i will indeed not find a data.

# %%
# %%sql
#
# SELECT
#     ws.type_of_water_source,
#     wq.subjective_quality_score,
#     v.visit_count
# FROM
#     water_source ws
# JOIN
#     visits v ON ws.source_id = v.source_id
# JOIN
#     water_quality wq ON v.record_id = wq.record_id
# WHERE
#     wq.subjective_quality_score = 10
#     AND v.visit_count = 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 218 rows affected.
# [('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
#  ('shared_tap', 10, 2),
# ...

# %% [markdown]
# I get 218 rows of data. But this should not be happening. I think some of the employees may have made mistakes. But errors are to be expected in data of this scale.
#
# We can advice the Pres to appoint an Auditor to check some of the data independently, and make sure we have the right information.

# %% [markdown]
# 5. Investigate pollution issues:
# Contamination/pollution data was recorded for well sources. Lets have a look at the table

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     well_pollution
# LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 10 rows affected.
# [('KiRu28935224', datetime.datetime(2021, 1, 4, 9, 17), 'Bacteria: Giardia Lamblia', 0.0, 495.898, 'Contaminated: Biological'),
#  ('AkLu01628224', datetime.datetime(2021, 1, 4, 9, 53), 'Bacteria: E. coli', 0.0, 6.09608, 'Contaminated: Biological'),
#  ('HaZa21742224', datetime.datetime(2021, 1, 4, 10, 37), 'Inorganic contaminants: Zinc, Zinc, Lead, Cadmium', 2.715, 0.0, 'Contaminated: Chemical'),
#  ('HaRu19725224', datetime.datetime(2021, 1, 4, 11, 4), 'Clean', 0.0288593, 9.56996e-05, 'Clean'),
#  ('SoRu35703224', datetime.datetime(2021, 1, 4, 11, 29), 'Bacteria: E. coli', 0.0, 22.5009, 'Contaminated: Biological'),
#  ('AkHa00070224', datetime.datetime(2021, 1, 4, 11, 42), 'Inorganic contaminants: Cadmium', 5.46739, 0.0, 'Contaminated: Chemical'),
#  ('HaSe21346224', datetime.datetime(2021, 1, 4, 11, 52), 'Clean', 0.0140376, 8.98989e-05, 'Clean'),
# ...

# %% [markdown]
# It looks like our scientists diligently recorded the water quality of all the wells. Some are contaminated with biological contaminants, while others are polluted with an excess of heavy metals and other pollutants. Based on the results, each well was classified as Clean, Contaminated: Biological or Contaminated: Chemical. It is important to know this because wells that are polluted with bio or other contaminants are not safe to drink. It looks like they recorded the source_id of each test, so we can link it to a source, at some place in Maji Ndogo.

# %% [markdown]
# In the well pollution table, the descriptions are notes taken by our scientists as text, so it will be challenging to process it. The
# biological column is in units of CFU/mL, so it measures how much contamination is in the water. 0 is clean, and anything more than
# 0.01 is contaminated.
# Let's check the integrity of the data. The worst case is if we have contamination, but we think we don't. People can get sick, so we
# need to make sure there are no errors here.

# %%
# %%sql
#
# # Writing a query that checks if the results is Clean but the biological column is > 0.01.
#
# SELECT
#     *
# FROM
#     well_pollution
# WHERE
#     results = "Clean"
#     AND biological > 0.01;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 64 rows affected.
# [('AkRu08936224', datetime.datetime(2021, 1, 8, 9, 22), 'Bacteria: E. coli', 0.0406458, 35.0068, 'Clean'),
#  ('AkRu06489224', datetime.datetime(2021, 1, 10, 9, 44), 'Clean Bacteria: Giardia Lamblia', 0.0897904, 38.467, 'Clean'),
#  ('SoRu38011224', datetime.datetime(2021, 1, 14, 15, 35), 'Bacteria: E. coli', 0.0425095, 19.2897, 'Clean'),
#  ('AkKi00955224', datetime.datetime(2021, 1, 22, 12, 47), 'Bacteria: E. coli', 0.0812092, 40.2273, 'Clean'),
#  ('KiHa22929224', datetime.datetime(2021, 2, 6, 13, 54), 'Bacteria: E. coli', 0.0722537, 18.4482, 'Clean'),
#  ('KiRu25473224', datetime.datetime(2021, 2, 7, 15, 51), 'Clean Bacteria: Giardia Lamblia', 0.0630094, 24.4536, 'Clean'),
#  ('HaRu17401224', datetime.datetime(2021, 3, 1, 13, 44), 'Clean Bacteria: Giardia Lamblia', 0.0649209, 25.8129, 'Clean'),
# ...

# %% [markdown]
# If we compare the results of this query to the entire table it seems like we have some inconsistencies in how the well statuses are
# recorded. Specifically, it seems that some data input personnel might have mistaken the description field for determining the clean-
# liness of the water.

# %% [markdown]
# It seems like, in some cases, if the description field begins with the word “Clean”, the results have been classified as “Clean” in the results column, even though the biological column is > 0.01.

# %% [markdown]
# When we work with real-world data we may find inconsistencies due to data being misinterpreted based on a description rather than its
# actual values. Let’s dive deeper into the cause of the issue with the biological contamination data.

# %% [markdown]
# One of the scientist mentioned that the descriptions should only have the word “Clean” if there is no biological contamination (and no chemical pollutants). Some data personnel must have copied the data from the scientist's notes into our database incorrectly. We need to find and remove the “Clean” part from all the descriptions that do have a biological contamination so this mistake is not made again.

# %% [markdown]
# The second issue has arisen from this error, but it is much more problematic. Some of the field surveyors have marked wells as Clean in
# the results column because the description had the word “Clean” in it, even though they have a biological contamination. So we need
# to find all the results that have a value greater than 0.01 in the biological column and have been set to Clean in the results column.

# %% [markdown]
# First, let's look at the descriptions. We need to identify the records that mistakenly have the word Clean in the description. However, it is important to remember that not all of our field surveyors used the description to set the results – some checked the actual data.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     well_pollution
# WHERE
#     description LIKE "Clean%_"
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 38 rows affected.
# [('AkRu06489224', datetime.datetime(2021, 1, 10, 9, 44), 'Clean Bacteria: Giardia Lamblia', 0.0897904, 38.467, 'Clean'),
#  ('KiRu25473224', datetime.datetime(2021, 2, 7, 15, 51), 'Clean Bacteria: Giardia Lamblia', 0.0630094, 24.4536, 'Clean'),
#  ('HaRu17401224', datetime.datetime(2021, 3, 1, 13, 44), 'Clean Bacteria: Giardia Lamblia', 0.0649209, 25.8129, 'Clean'),
#  ('AkRu07137224', datetime.datetime(2021, 3, 4, 13, 41), 'Clean Bacteria: Giardia Lamblia', 0.0656843, 18.2978, 'Clean'),
#  ('KiRu27205224', datetime.datetime(2021, 3, 13, 14, 17), 'Clean Bacteria: Giardia Lamblia', 0.0418018, 49.4281, 'Clean'),
#  ('AkHa00514224', datetime.datetime(2021, 4, 11, 12, 11), 'Clean Bacteria: Giardia Lamblia', 0.0305404, 22.0255, 'Clean'),
#  ('AmAm09776224', datetime.datetime(2021, 5, 23, 11, 28), 'Clean Bacteria: Giardia Lamblia', 0.0963821, 13.6574, 'Clean'),
# ...

# %% [markdown]
# The query returns 38 wrong descriptions.
#
#
# Now we need to fix these descriptions so that we don’t encounter this issue again in the future.
#
#
# Looking at the results we can see two different descriptions that we need to fix:
# 1. All records that mistakenly have Clean Bacteria: E. coli should updated to Bacteria: E. coli
# 2. All records that mistakenly have Clean Bacteria: Giardia Lamblia should updated to Bacteria: Giardia Lamblia
#
#
# The second issue we need to fix is in our results column. We need to update the results column from Clean to Contaminated: Biological where the biological column has a value greater than 0.01.

# %%
# %%sql
#
# # Now, when we change any data on the database, we need to be SURE there are no errors, as this could fill the database with
# # incorrect values. A safer way to do the UPDATE is by testing the changes on a copy of the table first.
#
# CREATE TABLE
#     md_water_services.well_pollution_copy
# AS (
#     SELECT
#         *
#     FROM
#         md_water_services.well_pollution
#     );
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# (pymysql.err.OperationalError) (1050, "Table 'well_pollution_copy' already exists")
# [SQL: # Now, when we change any data on the database, we need to be SURE there are no errors, as this could fill the database with
# # incorrect values. A safer way to do the UPDATE is by testing the changes on a copy of the table first.
#
# CREATE TABLE
#     md_water_services.well_pollution_copy
# AS (
#     SELECT
#         *
#     FROM
#         md_water_services.well_pollution
#     );]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# # Case 1a: Update descriptions that mistakenly mention `Clean Bacteria: E. coli` to `Bacteria: E. coli`
# UPDATE
#     well_pollution_copy
# SET
#     description = 'Bacteria: E. coli'
# WHERE
#     description = 'Clean Bacteria: E. coli';
# # Case 1b: Update the descriptions that mistakenly mention `Clean Bacteria: Giardia Lamblia` to `Bacteria: Giardia Lamblia
# UPDATE
#     well_pollution_copy
# SET
#     description = 'Bacteria: Giardia Lamblia'
# WHERE
#     description = 'Clean Bacteria: Giardia Lamblia';
# # Case 2: Update the `result` to `Contaminated: Biological` where `biological` is greater than 0.01 plus current results is `Clean`
# UPDATE
#     well_pollution_copy
# SET
#     result = 'Contaminated: Biological'
# WHERE
#     biological > 0.01 AND results = 'Clean'

# %%
# %%sql
#
# # checking if our errors are fixed
#
# SELECT
#     *
# FROM
#     well_pollution_copy
# WHERE
#     description LIKE "Clean_%"
#     OR (results = "Clean" AND biological > 0.01);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 0 rows affected.
# []

# %% [markdown]
# 0 results. We can now see that the the update was successful.
# We can choose to now update it on the original well pollution table, but I choose to leave it on the copy table and do future queries from it

# %% [markdown]
# Now Lets answer the MCQs below

# %%
# %%sql
#
# # Exploring the employee table
#
# SELECT
#     *
# FROM
#     employee
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [(0, 'Amara Jengo', '+99637993287', 'amara.jengo@ndogowater.gov', '36 Pwani Mchangani Road', 'Sokoto', 'Ilanga', 'Field Surveyor'),
#  (1, 'Bello Azibo', '+99643864786', 'bello.azibo@ndogowater.gov', '129 Ziwa La Kioo Road', 'Kilimani', 'Rural', 'Field Surveyor'),
#  (2, 'Bakari Iniko', '+99222599041', 'bakari.iniko@ndogowater.gov', '18 Mlima Tazama Avenue', 'Hawassa', 'Rural', 'Field Surveyor'),
#  (3, 'Malachi Mavuso', '+99945849900', 'malachi.mavuso@ndogowater.gov', '100 Mogadishu Road', 'Akatsi', 'Lusaka', 'Field Surveyor'),
#  (4, 'Cheche Buhle', '+99381679640', 'cheche.buhle@ndogowater.gov', '1 Savanna Street', 'Akatsi', 'Rural', 'Field Surveyor')]

# %% [markdown]
# Anwering some question to fetch out some data

# %%
# %%sql
#
# # Q1. What is the address of Bello Azibo?
#
# SELECT
#     address
# FROM
#     employee
# WHERE
#     employee_name = 'Bello Azibo';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [('129 Ziwa La Kioo Road',)]

# %%
# %%sql
#
# # Q2. What is the name and phone number of our microbiologist?
#
# SELECT
#     employee_name,
#     phone_number
# FROM
#     employee
# WHERE
#     position = 'Micro Biologist'
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [('Vuyisile Ghadir', '+99712584936')]

# %%
# %%sql
#
# # -- Q.3 What is the source_id of the water source shared by the most number of people? Hint: Use a comparison operator.
# # From the result, the source_id is AkRu05603224
#
# SELECT
#     *
# FROM
#     water_source
# ORDER BY
#     number_of_people_served DESC
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 5 rows affected.
# [('AkRu05603224', 'shared_tap', 3998),
#  ('HaRu19509224', 'shared_tap', 3998),
#  ('AmAs10911224', 'shared_tap', 3996),
#  ('AkRu04862224', 'shared_tap', 3996),
#  ('KiHa22867224', 'shared_tap', 3996)]

# %%
# %%sql
#
# # Q4. What is the population of Maji Ndogo? Hint: Start by searching the data_dictionary table for the word 'population'.
#
# SELECT
#     *
# FROM
#     data_dictionary
# WHERE description LIKE '%population%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('global_water_access', 'pop_n', 'The national population size estimate in thousands', 'float', ''),
#  ('global_water_access', 'pop_u', 'The urban population share estimate in percentage points (%)', 'float', '')]

# %%
# %%sql
#
# # now I can tell where the population is in the database. Its in the global_water_access table and the column name is 'pop_n'.
# #  And its estimated in 1000s ie; n*1000, where n is the estimated figure. From this info I can fetch the population of maji_ndogo
# # Hence population of Maji Ndogo is 27,628,100
#
# SELECT
#     *
# FROM
#     global_water_access
# WHERE
#     name = 'Maji Ndogo';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('Maji Ndogo', 'Sub-Saharan Africa', 2015, 27628.1, 36.0, 47.6, 31.4, 12.8, 8.2, 41.15, 36.68, 12.67, 9.49, 58.32, 22.57, 12.21, 6.89),
#  ('Maji Ndogo', 'Sub-Saharan Africa', 2020, 27628.1, 36.0, 47.6, 31.4, 12.8, 8.2, 41.15, 36.68, 12.67, 9.49, 58.32, 22.57, 12.21, 6.89)]

# %%
# %%sql
#
# # Q5. Which SQL query returns records of employees who are Civil Engineers residing in Dahabu or living on an avenue?
#
# SELECT
#     *
# FROM
#     employee
# WHERE
#     position = 'Civil Engineer'
#     AND (province_name = 'Dahabu' OR address LIKE '%Avenue%');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [(71, 'Jengo Rudo', '+99317854629', 'jengo.rudo@ndogowater.gov', '33 Angélique Kidjo Avenue', 'Amanzi', 'Dahabu', 'Civil Engineer'),
#  (81, 'Nia Vuyisile', '+99273841596', 'nia.vuyisile@ndogowater.gov', '52 Moroni Avenue', 'Sokoto', 'Rural', 'Civil Engineer')]

# %%
# %%sql
#
# #Q6. Create a query to identify potentially suspicious field workers based on an anonymous tip. This is the description we are given:
#
# #The employee’s phone number contained the digits 86 or 11.
# #The employee’s last name started with either an A or an M.
# #The employee was a Field Surveyor.
#
# SELECT
#     employee_name
# FROM
#     employee
# WHERE
#      (phone_number LIKE '%86%'
#     OR phone_number LIKE '%11%')
#     AND (employee_name LIKE '% A%'
#     OR employee_name LIKE '% M%')
#     AND position = 'Field Surveyor';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 2 rows affected.
# [('Bello Azibo',), ('Zuriel Matembo',)]

# %%
# %%sql
#
# #Q7. What is the result of the following query? Choose the most appropriate description of the results set.
#
# SELECT
#     *
# FROM
#     well_pollution
# WHERE
#     (description LIKE 'Clean_%' OR results = 'Clean')
#     AND biological < 0.01;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 4916 rows affected.
# [('HaRu19725224', datetime.datetime(2021, 1, 4, 11, 4), 'Clean', 0.0288593, 9.56996e-05, 'Clean'),
#  ('HaSe21346224', datetime.datetime(2021, 1, 4, 11, 52), 'Clean', 0.0140376, 8.98989e-05, 'Clean'),
#  ('AkRu05973224', datetime.datetime(2021, 1, 4, 13, 44), 'Clean', 0.084344, 6.2396e-05, 'Clean'),
#  ('AkHa00706224', datetime.datetime(2021, 1, 4, 16, 10), 'Clean', 0.0862577, 4.22834e-05, 'Clean'),
#  ('HaRu20773224', datetime.datetime(2021, 1, 7, 9, 8), 'Clean', 0.0599682, 2.42289e-05, 'Clean'),
#  ('AkRu04914224', datetime.datetime(2021, 1, 7, 11, 35), 'Clean', 0.050281, 9.42943e-05, 'Clean'),
#  ('HaSe20931224', datetime.datetime(2021, 1, 7, 11, 46), 'Clean', 0.0224843, 9.87848e-05, 'Clean'),
#  ('AmAm09579224', datetime.datetime(2021, 1, 7, 13, 2), 'Clean', 0.0830754, 1.10413e-05, 'Clean'),
#  ('KiHa23405224', datetime.datetime(2021, 1, 7, 15, 29), 'Clean', 0.0633972, 5.88518e-05, 'Clean'),
# ...

# %% [markdown]
# 4916 records are returned. This query describes the pollution samples that had an insignificant amount of biological contamination.

# %%
# %%sql
#
# # Q8. Which query will identify the records with a quality score of 10, visited more than once?
#
# SELECT
#     *
# FROM
#     water_quality
# WHERE
#     visit_count > 1
#     AND subjective_quality_score = 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1526 rows affected.
# [(59, 10, 2),
#  (67, 10, 3),
#  (85, 10, 4),
#  (128, 10, 5),
#  (137, 10, 2),
#  (232, 10, 3),
#  (263, 10, 6),
#  (269, 10, 2),
#  (271, 10, 3),
#  (317, 10, 4),
#  (318, 10, 7),
#  (358, 10, 4),
#  (363, 10, 2),
#  (378, 10, 2),
#  (398, 10, 8),
#  (431, 10, 5),
#  (436, 10, 6),
#  (439, 10, 5),
#  (441, 10, 3),
#  (450, 10, 3),
#  (459, 10, 7),
#  (460, 10, 4),
#  (463, 10, 6),
#  (470, 10, 4),
#  (476, 10, 8),
#  (488, 10, 5),
#  (498, 10, 5),
#  (508, 10, 7),
#  (566, 10, 6),
#  (618, 10, 2),
#  (630, 10, 8),
#  (632, 10, 6),
#  (656, 10, 3),
#  (662, 10, 7),
#  (730, 10, 7),
#  (741, 10, 8),
#  (749, 10, 8),
#  (752, 10, 2),
#  (758, 10, 4),
#  (801, 10, 2),
#  (817, 10, 5),
#  (818, 10, 3),
#  (819, 10, 2),
#  (850, 10, 2),
#  (869, 10, 3),
#  (894, 10, 3),
#  (904, 10, 4),
#  (905, 10, 3),
#  (911, 10, 6),
#  (918, 10, 4),
#  (921, 10, 7),
#  (930, 10, 4),
#  (932, 10, 5),
#  (937, 10, 5),
# ...

# %%
# %%sql
#
# #Updating Bello Azibo's number with his correct number '+99643864786'
#
# UPDATE employee
# SET phone_number = '+99643864786'
# WHERE employee_name = 'Bello Azibo';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "\n#Updating Bello Azibo's number with his correct number '+99643864786'\n\nUPDATE employee\nSET phone_number = '+99643864786'\nWHERE employee_name = 'Bello Azibo';\n\n")
#
# File c:\Users\irene2\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
# ...

# %%
# %%sql
#
# SELECT employee_name, phone_number
# FROM employee
# WHERE employee_name = 'Bello Azibo';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 1 rows affected.
# [('Bello Azibo', '+99643864786')]

# %%
# %%sql
#
# # Q10. How many rows of data are returned for the following query?
#
#
# SELECT
#     *
# FROM
#     well_pollution_copy
# WHERE
#     description IN ('Parasite: Cryptosporidium', 'biologically contaminated')
#     OR (results = 'Clean' AND biological > 0.01)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/md_water_services
# 570 rows affected.
# [('SoRu36278224', datetime.datetime(2021, 1, 4, 12, 24), 'Parasite: Cryptosporidium', 0.0, 485.162, 'Contaminated: Biological'),
#  ('HaDe16499224', datetime.datetime(2021, 1, 7, 12, 53), 'Parasite: Cryptosporidium', 0.0, 485.162, 'Contaminated: Biological'),
#  ('KiRu26584224', datetime.datetime(2021, 1, 8, 13, 10), 'Parasite: Cryptosporidium', 0.0, 485.162, 'Contaminated: Biological'),
#  ('KiZu31025224', datetime.datetime(2021, 1, 10, 14, 36), 'Parasite: Cryptosporidium', 0.0, 485.162, 'Contaminated: Biological'),
#  ('HaRu17300224', datetime.datetime(2021, 1, 16, 16, 47), 'Parasite: Cryptosporidium', 0.0, 485.162, 'Contaminated: Biological'),
#  ('SoRu35543224', datetime.datetime(2021, 1, 18, 9, 49), 'Parasite: Cryptosporidium', 0.0, 485.162, 'Contaminated: Biological'),
# ...
